# %% [markdown]
# # Week 9 handin

# %% [markdown]
# ## 01 Assignment
# ## Ex 1
# `Data = 'https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'`
# ### Download the data
#
# - Programatically download the data from the above link.
# - Import the data into a Pandas dataframe.
# - Show the head of the Pandas dataframe.
#
# ### Feature engineering
# - Reduce the dataset by:
#   - Make == Honda
#   - Fueltype == Gasoline
#   - Remove outliers. Hint: `df[column name'] < df['column name'].quantile(0.90)`
#   - Only use 2 features: 'Fuel Information.Highway mpg' and 'Engine Information.Engine Statistics.Horsepower'
#   - Normalize data (reduce values to be between 0 and 1)
#
# ### Linear regression
#
# - Perform linear regression where x = horsepower and y = mpg
# - What is the coefficient (slope) of your model? What does this number mean?
# - According to your model, what is `y` when `x=1`.
# - Show the regression line on a scatterplot with the other datapoints.

# %% [markdown]
# ## 02 Status
# Jeg har ikke lavet en regression line på mit scatterplot, men resten er.

# %% [markdown]
# ## 03 Solution part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import sklearn
from sklearn.linear_model import LinearRegression

# %%
#downloader csven til dataframe
url = 'https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
# redusere så dataframen kun indeholder Hondaer med fueltype gasoline
reduced_df = df.loc[df['Identification.Make']=='Honda' ]
reduced_df = reduced_df.loc[df['Fuel Information.Fuel Type']=='Gasoline']
reduced_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 105                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
# jeg ved ikke hvad der sker her 
reduced_df = reduced_df[reduced_df['Fuel Information.Highway mpg'] < reduced_df['Fuel Information.Highway mpg'].quantile(0.90)]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 105                 152                240                57
# 150                 152                240                57
# 341                 132                134               105
# 342                 132                134               105
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 105             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# ...

# %%
mpg = reduced_df[['Fuel Information.Highway mpg']].values
hp = reduced_df[['Engine Information.Engine Statistics.Horsepower']].values

# %%
model = LinearRegression(normalize=True)
model.fit(hp,mpg)
print('coefficient slope',model.score(hp,mpg))
print('y er ',model.predict([[1]]), 'når x er 1')

plt.scatter(hp,mpg)

plt.show()
# Out:
# coefficient slope 0.003552625087618555
# y er  [[26.50321782]] når x er 1
